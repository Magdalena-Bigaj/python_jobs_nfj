# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from time import sleep
from collections import Counter

# %%
def get_page (page):
    r= requests.get('https://nofluffjobs.com/pl/Python?page='+(str(page)))
    c= r.content
    soup= BeautifulSoup (c, 'html.parser')
    return soup
    
def display_technologies(requirements,tech):
    tech_dict = {i: x for i, x in enumerate(Counter(requirements).items())}
    df = pd.DataFrame.from_dict(tech_dict, orient='index', columns=[tech, 'number'])
    pd.set_option('display.max_rows', None)   
    df.sort_values(by=['number'], inplace=True, ascending= False)
    print (df)

def make_dict(list_req):
    return [item.strip() for sublist in list_req for item in sublist]


page= 1
list_req_must=[]
list_req_nice=[]
while True:
    soup= get_page(page)
    if (soup.find('a', {'class': 'jobs-link'}))== None:
        break
    job_sites= soup.find_all('a',{'target':'_self'}, href=True)
    for h in job_sites:
        link= h.get('href')
        if '/job/' in (link):
            try:
                if requests.Response() == 200:
                        break
                r= requests.get('https://nofluffjobs.com/'+(str(link.lstrip('/pl/'))), timeout=1000)
                c= r.content
                soup_job= BeautifulSoup (c, 'html.parser')        
                title= soup_job.find('h1').text
                requirements_must= list(l.text for l in list(soup_job.find_all('ul', {'class': 'mb-0 ng-star-inserted'})))
                rm = list((requirements_must)[0].split("  "))
                list_req_must.append(rm)
                try:
                    requirements_nice_to_have= (str(l.text).strip() for l in (soup_job.find('section', {'id': 'posting-nice-to-have'})))
                    rn= (list(requirements_nice_to_have)[1].split("  "))
                    list_req_nice.append(rn)
                except TypeError as e:    
                    pass
            except Exception as inst:
                print (inst)
    page +=1



display_technologies(make_dict(list_req_must), 'tech- must')
display_technologies(make_dict(list_req_nice), 'tech- nice_to_have')
# Out:
# list index out of range
# list index out of range
# list index out of range
#                                    tech- must  number
# 0                                      Python     311
# 22                                    English     148
# 4                                         SQL      94
# 5                                      Polish      84
# 60                                        AWS      81
# 2                                       Linux      79
# 3                                      Docker      74
# 1                                         Git      68
# 26                               English (B2)      68
# 101                                Kubernetes      52
# 38                                      Azure      46
# 71                                       Bash      45
# 13                                      CI/CD      39
# 114                                 Terraform      38
# 139                                   Jenkins      38
# 140                                      Java      36
# 59                                    Ansible      33
# 56                                 JavaScript      31
# 85                               English (C1)      28
# 31                                      Spark      25
# 6                                      Django      25
# 17                                        ETL      25
# 109                                    DevOps      24
# 46                                 PostgreSQL      22
# 99                                        GCP      19
# 12                                   REST API      17
# 45                                     GitLab      16
# 263                                       C++      15
# 43                                      React      15
# 68                                      Kafka      15
# 36                                       REST      14
# 39                                         C#      14
# 208                                  Selenium      13
# 75                                 AWS Lambda      13
# 27                                   Big Data      12
# 107                                TypeScript      12
# 105                                     Scala      12
# 10                                      NoSQL      12
# 8                                      pytest      12
# 190                          Machine learning      12
# 194                           CI/CD Pipelines      11
# 142                                     MySQL      11
# 237                                PowerShell      10
# 47                                      Shell      10
# 195                                    Groovy      10
# 88                           Machine Learning      10
# 76                              Microservices      10
# 33                                        OOP      10
# 89                                    PyTorch      10
# 72                                    Airflow      10
# 121                                    pandas       9
# 146                                 Snowflake       9
# 213                                      Jira       9
# 69                           Data engineering       9
# 276                                    Puppet       9
# 86                                         QA       9
# 148                      Communication skills       8
# 189                                      Helm       8
# 78                                       Unix       8
# 116                           Design Patterns       8
# 164                            CloudFormation       8
# 87                                         AI       8
# 102                  English (B2) Polish (B2)       8
# 127                                     Cloud       8
# 50                               scikit-learn       8
# 238                                   Windows       7
# 32                                    PySpark       7
# 112                     Google Cloud Platform       7
# 282                                       TCP       7
# 77                                     Hadoop       7
# 161                                    AWS S3       7
# 104                                Databricks       7
# 96                                      NumPy       7
# 182                                      .NET       7
# 106                        Azure Data Factory       7
# 66                                      Redis       7
# 16                                   BigQuery       6
# 184                                      HTTP       6
# 279                                Prometheus       6
# 170                                   Grafana       6
# 119              English (B2) Polish (NATIVE)       6
# 169                             Elasticsearch       6
# 239                                       IaC       6
# 255                                Confluence       6
# 163                               API Gateway       6
# 25                                Team player       6
# 318                                         C       6
# 58                                    MongoDB       6
# 326                                      Perl       5
# 108                                   Node.js       5
# 321                            GitHub Actions       5
# 176                                       PHP       5
# 29                            Problem solving       5
# 37                                  Hungarian       5
# 143                                    Oracle       5
# 218                                       NLP       5
# 136                                TensorFlow       5
# 408                             Progress Chef       5
# 9                                       RDBMS       5
# 197                                      SDLC       5
# 199                        AWS CloudFormation       5
# 120                                      Glue       5
# 253                                        Go       5
# 240                                  CircleCI       5
# 7                                       Flask       5
# 210                              Azure DevOps       5
# 137                                     Keras       4
# 366                                    Appium       4
# 372                                      Ruby       4
# 368                                        UI       4
# 149                                    Golang       4
# 129                                       BDD       4
# 158                                       RDS       4
# 159                                Amazon RDS       4
# 290                                   Cypress       4
# 283                                       DNS       4
# 165                                       IAM       4
# 214                                       AKS       4
# 275                                      SaaS       4
# 260                                 OpenShift       4
# 258                                 Bitbucket       4
# 257                                    GitHub       4
# 193                            Virtualization       4
# 256                                      SOAP       4
# 206                                 Protocols       4
# 226                  Polish (B2) English (B2)       4
# 220                                     Nginx       4
# 216                                     MLOps       4
# 252                           Robot Framework       4
# 11                                        ORM       4
# 42                               English (B1)       4
# 70                        English (B2) Polish       4
# 21                                      Excel       4
# 35                   English (C1) Polish (C1)       4
# 122                                 AWS Cloud       4
# 44                                     Vue.js       4
# 410                                    Tomcat       3
# 24                                      linux       3
# 419                                Azure Data       3
# 269                                        CI       3
# 264                                       ARM       3
# 40                                    FastAPI       3
# 261                                    VMware       3
# 41                                     Celery       3
# 259                                  TeamCity       3
# 28                                Proactivity       3
# 302                                   Angular       3
# 51                                     OpenCV       3
# 432                                    MS SQL       3
# 245                                   Gherkin       3
# 241                                    Bamboo       3
# 198                                   AWS EC2       3
# 228                              Apache Spark       3
# 222                           Computer vision       3
# 215                                    MLflow       3
# 73                                        IoT       3
# 209                               Azure Cloud       3
# 48                                         JS       3
# 211                                      IaaS       3
# 369                                   AWS ECS       3
# 131                  English (B2) Polish (C1)       3
# 365                                    Kotlin       3
# 332                          Azure Databricks       3
# 156                                CloudWatch       3
# 348                                  Security       3
# 349                                    Spring       2
# 247                            Apache Airflow       2
# 246                              Unit testing       2
# 347                                  Networks       2
# 242                                 Travis CI       2
# 440                                 Oracle DB       2
# 57                        Relational database       2
# 233                                Statistics       2
# 232                                  Cucumber       2
# 389                                SQL Server       2
# 230                                    Kanban       2
# 344                                   Postman       2
# 61                                      Agile       2
# 225                                      ITIL       2
# 367                                   Bitrise       2
# 62                         Hungarian Language       2
# 450                                Amazon EKS       2
# 217                             Deep learning       2
# 364                                     Swift       2
# 358                             Azure Synapse       2
# 371                                       TLS       2
# 337                  Polish (C2) English (C1)       2
# 340                                     Scrum       2
# 417                              Blob Storage       2
# 400                                    ArgoCD       2
# 401                                 Kustomize       2
# 295                Microservices architecture       2
# 316                                    Pulumi       2
# 23                                        git       2
# 289                                     ISTQB       2
# 414                               Bash script       2
# 130                                       DDD       2
# 212                                      PaaS       2
# 416                                       WAF       2
# 418                                 Cosmos DB       2
# 387                                  Big data       2
# 19                            Data management       2
# 379                                     OWASP       2
# 271                               Polish (C1)       2
# 328                                     Druid       2
# 330                                     T-SQL       2
# 331                                 Azure SQL       2
# 262                             Cybersecurity       2
# 333                                        CD       2
# 334                                     Maven       2
# 336                                   Tableau       2
# 128                                       TDD       2
# 359                                       DWH       2
# 187                                      HTML       2
# 201                                       SQS       2
# 188                                       CSS       2
# 150                                       FTP       2
# 113                                       PUB       2
# 117                                   Testing       2
# 192                               Artifactory       2
# 175                                    Splunk       2
# 171                                    Kibana       2
# 141                              AWS Redshift       2
# 162                                CloudFront       2
# 124                              AWS DynamoDB       2
# 172                              Data science       2
# 202                                       SNS       2
# 167                                  Logstash       2
# 100                                      IaaC       2
# 97                              Data modeling       2
# 74                      Azure Data Lake Store       2
# 133                                 Bootstrap       2
# 134                                    JQuery       2
# 166                                    Driven       2
# 126                           Microsoft Azure       2
# 135                  Polish (C1) English (C1)       2
# 181                                   MariaDB       2
# 399                                   AWS EKS       1
# 392                                   AWS CDK       1
# 491                                     Flink       1
# 490                                   Kinesis       1
# 489                                  Centrify       1
# 488                                      LDAP       1
# 388                                    PL/SQL       1
# 487                                    Sybase       1
# 390                                   Web API       1
# 403                                 ELK Stack       1
# 391                                      Chef       1
# 393                          Customer focused       1
# 398                       Amazon Web Services       1
# 485                                       IBM       1
# 402                                   Datadog       1
# 394                         Business oriented       1
# 395                                    Apache       1
# 404                            AWS CloudWatch       1
# 405                                       CSP       1
# 396                               Helm charts       1
# 386                              English (C2)       1
# 397                                       K8s       1
# 486                                     Swarm       1
# 454                                       PAM       1
# 385                                       CDN       1
# 384                                  DynamoDB       1
# 503                           HashiCorp Vault       1
# 362                               Team Player       1
# 363          Leadership and management skills       1
# 18                                 Governance       1
# 15                                   Collibra       1
# 502                                       CDK       1
# 501                          Apache ZooKeeper       1
# 370                                      SAFe       1
# 500                                       WAN       1
# 14                                Polish (B2)       1
# 373                                   Xamarin       1
# 374                                     Telco       1
# 499                                       LAN       1
# 375                            Multithreading       1
# 376                                       CEH       1
# 498                        Bash/Python/Golang       1
# 497                                 Spark SQL       1
# 377                              Cryptography       1
# 496                           Azure Data Lake       1
# 495                               Informatica       1
# 378                                Pentesting       1
# 494                                    Talend       1
# 493                                      Hive       1
# 492                                     Storm       1
# 407                               Autoscaling       1
# 380                                     Mocha       1
# 381                                   Jasmine       1
# 382                               Material UI       1
# 383                                       ELB       1
# 406                                      GoCD       1
# 412                                CloudTrail       1
# 484                                  MuleSoft       1
# 462                                      J2EE       1
# 435                         Analytical skills       1
# 468                                 Puppeteer       1
# 467                                    Gerrit       1
# 466                                 Hibernate       1
# 361                         Critical thinking       1
# 437                                       STL       1
# 465                                   WildFly       1
# 438                  Golng/ C#, C/C++/ Python       1
# 439                            Data analytics       1
# 464                                       JSP       1
# 463                                    jQuery       1
# 441                   Database administration       1
# 442                                   SnowSQL       1
# 443                                  SnowPipe       1
# 461                                       EJB       1
# 409                                     Istio       1
# 444                                    hadoop       1
# 460                                       VPN       1
# 445                                    docker       1
# 459                                       ECS       1
# 446                                 Big Query       1
# 447                                Linux/Unix       1
# 448                      Interpersonal skills       1
# 458                                 .NET CORE       1
# 449                                       GIT       1
# 457                                    TCP/IP       1
# 456                                       EDR       1
# 451                                 Key Vault       1
# 452                                      SOAR       1
# 455                                      CASB       1
# 434                                        bi       1
# 433           Hungarian (NATIVE) English (B2)       1
# 431                               Spring Boot       1
# 430                            Windows Server       1
# 411                                    Script       1
# 453                                      SIEM       1
# 413                                CodeDeploy       1
# 483                                      SAML       1
# 482                                     OAuth       1
# 481                                       VBA       1
# 415                               Service Bus       1
# 480                           Cloud computing       1
# 479                                    Dagger       1
# 420                                 Data Lake       1
# 421                         AWS, Azure or GCP       1
# 422                   API calls/FTP downloads       1
# 423                                  DB table       1
# 478                                       iOS       1
# 424                                   ETL/ELT       1
# 477                           Micro Focus UFT       1
# 425    Enterprise Data Platforms technologies       1
# 426         •\tExperience in data acquisition       1
# 427  •\tBachelor's degree in Computer Science       1
# 428                                      YAML       1
# 476                           Tricentis Tosca       1
# 475                            Katalon Studio       1
# 474                                       SAP       1
# 473                                       ERP       1
# 472                                       DMS       1
# 471                                       CRM       1
# 470                              Rest-Assured       1
# 469                                    SoapUI       1
# 429                             Load balancer       1
# 436                        Good coding skills       1
# 317                                      FPGA       1
# 360                         Cloud environment       1
# 357                                      ADLS       1
# 65                                 OAuth, JWT       1
# 67                                    RabbitM       1
# 207                       English (C1) Polish       1
# 205                         Amazon CloudWatch       1
# 204                                       VPC       1
# 203                                Amazon SQS       1
# 200                                   Route53       1
# 79                                    DNA-Seq       1
# 80                                    RNA-Seq       1
# 196                                    Gradle       1
# 81                                        HPC       1
# 82                      Django REST Framework       1
# 83                         Project management       1
# 191                           Design thinking       1
# 84                         Process management       1
# 64                          DRF/Flask/FastAPI       1
# 63                                 Python 3.x       1
# 219                                   Varnish       1
# 236                                     spaCy       1
# 248                      Domain Driven Design       1
# 244                                     CMake       1
# 243                                  Conan.io       1
# 53                                    banking       1
# 54                             Python scripts       1
# 55                                        ES6       1
# 235                                     SciPy       1
# 221                         Automated testing       1
# 234                                Matplotlib       1
# 231                                Automation       1
# 229                             Visual Studio       1
# 227                                  Kubeflow       1
# 224                                     Relay       1
# 223                                   GraphQL       1
# 90                              User Research       1
# 186                                Oscyloskop       1
# 185                                 Multimetr       1
# 147                                  database       1
# 155                             Design System       1
# 154                                      Vuex       1
# 153                                 DataBriks       1
# 152                                       ELT       1
# 151                                   PowerBI       1
# 115               The Python Standard Library       1
# 145                                  AWS Glue       1
# 111                    Hungarian (B1) English       1
# 144                   Version Control Systems       1
# 118                                       DRF       1
# 123                                    Athena       1
# 138                                 Rabbit MQ       1
# 125                            Docker Compose       1
# 132              Polish (NATIVE) English (B2)       1
# 157                                       SSO       1
# 110                           Team management       1
# 91                         Data visualization       1
# 93                      Django Rest Framework       1
# 183                                       AWK       1
# 92               English (C1) Polish (NATIVE)       1
# 180                                       css       1
# 179                                      html       1
# 178                                postgreSQL       1
# 177                                javascript       1
# 174                                 ETL tools       1
# 160                             Apache Aurora       1
# 173                          Data Integration       1
# 94                   Polish (C2) English (B2)       1
# 95                                     Pandas       1
# 168                                      HDFS       1
# 98                               Data mapping       1
# 103                  Polish (B1) English (B1)       1
# 249                                Playwright       1
# 250                                       API       1
# 251               Hungarian (C1) English (C2)       1
# 315                              Google Cloud       1
# 324                                     agile       1
# 323                                       UML       1
# 322                                 GitLab CI       1
# 20                            Data governance       1
# 320                    Python/bash/Powershell       1
# 319                                       SES       1
# 314                     Google cloud platform       1
# 327                                   Java EE       1
# 313                                      Sass       1
# 312                                      LESS       1
# 311                                      CSS3       1
# 310                                     HTML5       1
# 309                                  Analysis       1
# 308                            Analyzing data       1
# 325               Object-oriented programming       1
# 329                                    Presto       1
# 306                   Clouds Native Landscape       1
# 350                                     JUnit       1
# 356                          Data Engineering       1
# 355                           Data warehouses       1
# 354                           ETL development       1
# 353                            Data modelling       1
# 352                                     Spock       1
# 351                                   Mockito       1
# 346                                  SpecFlow       1
# 335                                     Bazel       1
# 345                                    JMeter       1
# 343                                       Geb       1
# 342                                 WebDriver       1
# 341                                        js       1
# 339                              Google cloud       1
# 338                                   Magento       1
# 307                                       dbt       1
# 305                            Cloud Composer       1
# 52                   Polish (C1) English (B2)       1
# 272                           Test frameworks       1
# 30                        Polish (C1) English       1
# 278                                    Zabbix       1
# 277                                      SCCM       1
# 34                        Python and/or Scala       1
# 274                                    PyTest       1
# 273                              Git (Github)       1
# 270                                       ROS       1
# 281                                   vagrant       1
# 268                                       SVN       1
# 267                                 Antivirus       1
# 266                                       CLI       1
# 265                                       SDK       1
# 49                                      Conda       1
# 254                                       SSL       1
# 280                                  Graphite       1
# 284               Natural language processing       1
# 304                                       VCS       1
# 296                    Infrastructure as Code       1
# 303                                  Ember.js       1
# 301                         agile methodology       1
# 300                                 Docker/CI       1
# 299                                     macOS       1
# 298                                  Perforce       1
# 297                               Photography       1
# 294                                Serverless       1
# 285                                        IP       1
# 293             languages: Python (preferred)       1
# 292      Testing: Robot Framework (preferred)       1
# 291                              GitLab CI/CD       1
# 288                                      JSON       1
# 287                                       XML       1
# 286                                      VLAN       1
# 504                              Architecture       1
#                         tech- nice_to_have  number
# 8                                      AWS      36
# 32                                  Docker      33
# 59                              Kubernetes      29
# 82                                  Polish      22
# 30                                   Azure      20
# 60                              JavaScript      18
# 29                               Terraform      17
# 23                                   Linux      16
# 162                                  Spark      14
# 53                                     GCP      13
# 100                                   Java      13
# 7                                    React      12
# 35                           Elasticsearch      12
# 3                               PostgreSQL      12
# 46                                     Git      11
# 34                                 Grafana      11
# 109                                Ansible      11
# 72                                   Kafka      10
# 49                              TensorFlow      10
# 48                                 PyTorch      10
# 90                                     CSS      10
# 1                                   Celery      10
# 20                                 English       9
# 50                                 Airflow       9
# 194                             Prometheus       9
# 91                                    HTML       9
# 69                                  DevOps       9
# 25                                    Bash       8
# 123                                Jenkins       8
# 99                                  Python       7
# 2                                    Redis       7
# 148                                 Hadoop       7
# 71                                  pandas       7
# 93                                   CI/CD       7
# 17                             Polish (B2)       7
# 24                                     C++       7
# 22                                REST API       7
# 121                                     C#       7
# 86                              TypeScript       6
# 117                                   Jira       6
# 95                                    REST       6
# 70                                   NumPy       6
# 67                                      AI       6
# 66                        Machine Learning       6
# 75                                 Node.js       6
# 83                           Microservices       6
# 0                                   Django       6
# 27                                   Scala       6
# 41                                   MySQL       6
# 21                                   Flask       6
# 14                                   Keras       6
# 38                         Azure Data Lake       5
# 161                        Problem solving       5
# 118                               BigQuery       5
# 87                                 MongoDB       5
# 16                        Machine learning       5
# 31                                Selenium       5
# 36                                  Kibana       5
# 160                            Proactivity       5
# 45                             Azure Cloud       5
# 130                                  Cloud       5
# 134                                  NoSQL       5
# 140                                    SQL       4
# 85                            scikit-learn       4
# 4                    Google cloud platform       4
# 125                           AWS DynamoDB       4
# 39                      Azure Data Factory       4
# 97                                  GitHub       4
# 230                                Tableau       4
# 5                                       Go       4
# 55                                   Scrum       4
# 101                                 Golang       3
# 204                              AWS Cloud       3
# 202                                Datadog       3
# 314                               Power BI       3
# 105                               Big data       3
# 92                                     PHP       3
# 94                              AWS Lambda       3
# 139                                      R       3
# 110                                    XML       3
# 201                              Cassandra       3
# 13                                    CUDA       3
# 102                                   .NET       3
# 206                                Cypress       3
# 212                               Cucumber       3
# 191                             Confluence       3
# 56                             Team player       3
# 167                      Critical thinking       3
# 63                                      UX       3
# 42                              Azure Data       3
# 68                           Deep learning       3
# 196                              Snowflake       3
# 28                                     IaC       3
# 44                               Cosmos DB       3
# 9                             English (B2)       3
# 207                                    ETL       2
# 287                             Databricks       2
# 286                           AWS Redshift       2
# 182                                   SDLC       2
# 124                               RabbitMQ       2
# 205                                    TDD       2
# 10                                     c++       2
# 183                                 Groovy       2
# 133                            API Gateway       2
# 200                               Druid.io       2
# 185                                AWS EC2       2
# 135                        Design Patterns       2
# 147                                    dbt       2
# 195                                   Helm       2
# 137                         CloudFormation       2
# 138                                AWS CDK       2
# 305                                    DNS       2
# 154                                    SNS       2
# 153                             Amazon SQS       2
# 141                         Virtualization       2
# 152                                    SQS       2
# 199                                  MLOps       2
# 219                               Security       2
# 288                                 Puppet       2
# 238                               Teamwork       2
# 106            Natural language processing       2
# 64                                      UI       2
# 76                                 Angular       2
# 40                        Azure Databricks       2
# 257                              Azure IoT       2
# 226                                  ISTQB       2
# 88                                 FastAPI       2
# 89                                 GraphQL       2
# 15                            Scikit-learn       2
# 96                                DynamoDB       2
# 103                                    NLP       2
# 262                                  Cisco       2
# 33                         CI/CD Pipelines       2
# 107                                     ML       2
# 12                         Computer vision       2
# 111                                   Hive       2
# 51                                 PySpark       2
# 57                    Communication skills       2
# 263                                   LDAP       2
# 285                             PowerShell       1
# 250                                    BDD       1
# 245                             Low Energy       1
# 277                                 Anthos       1
# 249                                    npm       1
# 248                        Ultra Wide Band       1
# 278                          Elastic Stack       1
# 279                                      C       1
# 246                                 Thread       1
# 247                                 Matter       1
# 284                            Wireframing       1
# 280                                    IoT       1
# 281                                    K8s       1
# 283                                   BASH       1
# 251                                  Dutch       1
# 282                                  CISCO       1
# 269                                 DP-201       1
# 255                                Eclipse       1
# 252                  Distributed computing       1
# 274                          AWS SageMaker       1
# 270                                 DP-203       1
# 271                                 AZ-400       1
# 267                                  mongo       1
# 266                                 Presto       1
# 265                             Amazon EKS       1
# 272  Technical Leadership and Architecture       1
# 273                       Jupyter Notebook       1
# 264                       Couchbase Server       1
# 261                              Palo Alto       1
# 253                                  Spock       1
# 260                              Blue Coat       1
# 259                                 VMware       1
# 258                             E-commerce       1
# 256                                 Vaadin       1
# 268                                Routing       1
# 254                                    sbt       1
# 275                                 ArgoCD       1
# 276                                  Istio       1
# 347                             Delta lake       1
# 311                          IBM DataStage       1
# 289                     Project management       1
# 290                                Gherkin       1
# 324                          MicroStrategy       1
# 353                               Big Data       1
# 325                 JavaScript programming       1
# 326                                     Qt       1
# 327                                 OpenGL       1
# 328                        Microsoft Azure       1
# 329                           Data factory       1
# 330                                Elastic       1
# 331                                  CISSP       1
# 332                                   CISM       1
# 352                                    ORC       1
# 351                                   Avro       1
# 333                                 GitLab       1
# 350                                Parquet       1
# 334                                 Consul       1
# 335                                   CCNA       1
# 336                                    BGP       1
# 337                           Cryptography       1
# 338                                    PKI       1
# 339                                   HTTP       1
# 340                                    SSH       1
# 349                                  Proto       1
# 341                                   SNMP       1
# 342                                 Syslog       1
# 343                              SQL/NoSQL       1
# 344                                    ECS       1
# 345                            Apache Hudi       1
# 346                         Apache Iceberg       1
# 348                                   JSON       1
# 323                              Big Query       1
# 243                                 ZigBee       1
# 322                             Quicksight       1
# 303                                InfoSec       1
# 291                                    iOS       1
# 292                                 German       1
# 293                                  Nginx       1
# 294                             ambassador       1
# 295                                Graylog       1
# 296                      CKA certification       1
# 297   Azure certification - AZ-104, AZ-305       1
# 298                                    BLE       1
# 299                                   RTLS       1
# 300                           Google cloud       1
# 301                                 FinOps       1
# 354                                    JVM       1
# 302                        MySQL Databases       1
# 304                                   DHCP       1
# 321                            Data Studio       1
# 306                                  Proxy       1
# 307                               Logstash       1
# 308                            Informatica       1
# 309                                Pentaho       1
# 310                                   SSIS       1
# 312                               Cloudera       1
# 313                        Amazon Redshift       1
# 315                                    SAP       1
# 316                                  TIBCO       1
# 317                                  Flink       1
# 318                        Spark Streaming       1
# 319                                  Storm       1
# 320                             Map Reduce       1
# 244                             Bluethooth       1
# 178                                 Sentry       1
# 242                                    MSC       1
# 241                              Bluetooth       1
# 115                                seaborn       1
# 116                             Salesforce       1
# 119                                  OAuth       1
# 120                                   OIDC       1
# 122                                 Crypto       1
# 126                            AWS Amplify       1
# 127                            AWS Cognito       1
# 128                            AWS Gateway       1
# 129                         AWS CloudWatch       1
# 131                                MariaDB       1
# 132                        ML Ops concepts       1
# 136                                   SaaS       1
# 142                         Apache Airflow       1
# 143                           Apache Spark       1
# 144                                 Lambda       1
# 145                                   SOAP       1
# 146                                   Perl       1
# 149                                 Looker       1
# 150                               Robotics       1
# 151                                Vuetify       1
# 155                             CloudFront       1
# 156                     AWS Media Services       1
# 157                        Team management       1
# 158                                 Kanban       1
# 159                                   NiFi       1
# 114                             Matplotlib       1
# 113                                 Pandas       1
# 112                           Azure DevOps       1
# 61                                 Next.js       1
# 6                                       JS       1
# 11                                  OpenCV       1
# 18                                 KafkaMQ       1
# 19                                    APIS       1
# 26                   Continous integration       1
# 37                                InfluxDB       1
# 43                        Data engineering       1
# 47                                   Conda       1
# 52                              SQLAlchemy       1
# 54                                   Redux       1
# 58                                PythonRQ       1
# 62                                  Gatsby       1
# 108                    Amazon Web Services       1
# 65                             Prototyping       1
# 73                                AWS Glue       1
# 74                          Step Functions       1
# 77               Statistical data analysis       1
# 78                        NGS for Oncology       1
# 79                     Attention to detail       1
# 80                         Coaching Skills       1
# 81                         Quality control       1
# 84                             A/B Testing       1
# 98                    Serverless computing       1
# 104                       Web technologies       1
# 163           Data Visualization Libraries       1
# 164                              Plotly.js       1
# 165                               Chart.js       1
# 225                                Labview       1
# 213                                   RHEL       1
# 214                                 CentOS       1
# 215                            Polish (B1)       1
# 216                           Hugging Face       1
# 217                      Docker containers       1
# 218                                   SoC2       1
# 220                        Robot Framework       1
# 221                             Protractor       1
# 222                             Playwright       1
# 223                                 Vector       1
# 224                                     NI       1
# 227                                reactJS       1
# 210                                    SRE       1
# 228                                    AKS       1
# 229                                 Athena       1
# 231                                   Qlik       1
# 232                                 Vue.js       1
# 233                                     VR       1
# 234                             Blockchain       1
# 235                                  RDKit       1
# 236                        Cheminformatics       1
# 237                         Bioinformatics       1
# 239                      Business oriented       1
# 240                         Customer focus       1
# 211                                    R&D       1
# 209                                 Kotlin       1
# 166                            Chartist.js       1
# 180                            WebAssembly       1
# 168                                Webpack       1
# 169                 Functional programming       1
# 170                                    PLC       1
# 171                                    CAN       1
# 172                               PROFINET       1
# 173                               PROFIBUS       1
# 174                               ETHERCAT       1
# 175                            ETHERNET/IP       1
# 176                                   Odoo       1
# 177                        Google BigQuery       1
# 179                           Apache Kafka       1
# 181                                 Gradle       1
# 208                                 MS SQL       1
# 184                                    IAM       1
# 186                     AWS CloudFormation       1
# 187                                 AWS S3       1
# 188                                Route53       1
# 189                                    VPC       1
# 190                      Amazon CloudWatch       1
# 192                            Forecasting       1
# 193                                  Boost       1
# 197                                 MATLAB       1
# 198                                  RDBMS       1
# 203                        Shell Scripting       1
# 355                              OpenShift       1
